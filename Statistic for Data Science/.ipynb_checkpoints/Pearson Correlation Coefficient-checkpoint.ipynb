# %% [markdown]
# ## Pearson Correlation Coefficient
#
# - The most commonly used linear correlation coeficient
# - Values Range ( -1 to 1 )
# - (-1) -> Perfect negative linear relationship
# - (0) No linear relationship
# - 1: Perfect positive linear relationship
#
# Correlation does not imply causation: Just because two variables are correlated does not mean one causes the other.

# %% [markdown]
# ### Pearson Correlation Coefficient - Example
#
# | Person | Hours Studied | Exam Score |
# |--------|---------------|------------|
# |    1   |       2       |     50     |
# |    2   |       4       |     60     |
# |    3   |       6       |     65     |
# |    4   |       8       |     70     |
# |    5   |       10      |     85     |
#
# 1. Find the Mean of Hours studied and Exam Score
# 2. Calculate the Deviations for Hours and Exam Score for each person
# 3. Multiply the Hours and Score Deviations for each student.
# 4. Square the deviations for Hours and Score for each Person then sum
# 5. Input the values from steps 3 and 4 into the Formula

# %%
# importing libraries

import numpy as np
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Example 1: Manual Calculation

x = [5, 11, 21, 30]
y = [8, 17, 24, 33]

# step 1
mean_x = np.mean(x)
mean_y = np.mean(y)

# step 2
numerator = np.sum((x - mean_x) * (y - mean_y))
denominator = np.sqrt(np.sum((x - mean_x)**2) * np.sum((y - mean_y)**2))

r = numerator / denominator
r
# Out:
# 0.9911564424693111

# %%
# Example 2: Pearson Correlation Coefficient calcualtion using Numpy

r_numpy = np.corrcoef(x,y)[0,1]
r_numpy
# Out:
# 0.9911564424693111

# %%
# Example 3: Using Scipy

r_scipy, p_value = pearsonr(x,y)
print(r_scipy)
print(p_value)
# Out:
# 0.9911564424693111
# 0.008843557530688884

# %%
# Example 4: Using Pandas

# creating the df
data_pandas = {"x": [5, 11, 21, 30], "y": [8, 17, 24, 33]}
df = pd.DataFrame(data)

# calculation of corr
r_pandas = df["x"].corr(df["y"])
r_pandas
# Out:
# 0.9911564424693111

# %%
# Example 5: Visualization Using Scatter Plot

# calculating the slope and intercept 

m, b = np.polyfit(df["x"], df["y"], 1)
y_line = m * df["x"] + b


plt.figure(figsize = (10,5))
plt.scatter(x, y, color = "blue", label = "Data Points")
plt.plot(df["x"], y_line, color = "red", label = f"Line of Best Fit: y = {m:.2f}x + {b:.2f}")
plt.title("x vs y with Line of Best Fit")
plt.xlabel("x_values")
plt.ylabel("y_values")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Example 6: Correlation Matrix

correlation_matrix = np.corrcoef(x,y)

plt.figure(figsize = (10,6))
sns.heatmap(data = correlation_matrix, annot = True, cmap = "coolwarm", cbar = True, square = True, 
            fmt = ".2f", xticklabels = ["x","y"], yticklabels = ["x","y"] )
plt.title("Correlation Matrix Heatmap")
plt.show()
