# %%
# Link To Grab data
#https://www.espncricinfo.com/records/highest-career-batting-average-282910

# grab data from website and export to m.excel
# convert file into csv file

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Data Analyst\Cricket Test Match data\CricketTestMatchData.csv")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
pd.set_option('display.max_rows',70)

# %%
# rename multiple Columns in a list   --- using dictionaries
df = df.rename(columns = {'Mat': 'Matches', 'NO':'Not_Outs', 'HS': 'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR': 'Battling_Strike_Rate' })

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2               269*  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4               270*  60.83        416+                 56.00   10   5  2
#
#     4s  6s
# 0  626   6
# 1  141  23
# 2  186   5
# 3  246  11
# 4  104   1

# %%
# Checking Null values
df.isnull().any()
# Out:
# Player                  False
# Span                    False
# Matches                 False
# Inns                    False
# Not_Outs                False
# Runs                    False
# Highest_Inns_Score      False
# Ave                     False
# Balls_Faced              True
# Battling_Strike_Rate     True
# 100                     False
# 50                      False
# 0                       False
# 4s                      False
# 6s                      False
# dtype: bool

# %%
# investigating the Null Values in specific column
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                   NaN   15  19  6
# 16                220  56.68         NaN                   NaN   15  14  1
# 57               144*  48.79         NaN                   NaN    5   6  3
#
#      4s  6s
# 8   258   2
# 16  107  11
# 57   51   0

# %%
# replace the null values with 0
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
#Checking the replaced values
df[df["Player"]=="ED Weekes (WI)"]
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                207  58.61           0                   NaN   15  19  6
#
#     4s  6s
# 8  258   2

# %%
df[df["Battling_Strike_Rate"].isna()== 1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                 207  58.61           0                   NaN   15  19  6
# 16                220  56.68           0                   NaN   15  14  1
# 57               144*  48.79           0                   NaN    5   6  3
#
#      4s  6s
# 8   258   2
# 16  107  11
# 57   51   0

# %%
df["Battling_Strike_Rate"] = df["Battling_Strike_Rate"].fillna(0)

# %%
df[df["Player"]=="ED Weekes (WI)"]
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                207  58.61           0                   0.0   15  19  6
#
#     4s  6s
# 8  258   2

# %%
#selecting multiple rows base on Column name
df[df["Player"].isin(["ED Weekes (WI)","CL Walcott (WI)","Hon.FS Jackson (ENG)"])]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 16       CL Walcott (WI)  1948-1960       44    74         7  3798
# 57  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 8                 207  58.61           0                   0.0   15  19  6
# 16                220  56.68           0                   0.0   15  14  1
# 57               144*  48.79           0                   0.0    5   6  3
#
#      4s  6s
# 8   258   2
# 16  107  11
# 57   51   0

# %%
#checking duplicates
df.duplicated().any()
# Out:
# True

# %%
# investigating duplicated data base on rows
df[df["Player"].duplicated()==1]
# Out:
#             Player       Span  Matches  Inns  Not_Outs  Runs  \
# 11  GS Sobers (WI)  1954-1974       93   160        21  8032
# 15  JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 53   V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50   0  \
# 11               365*  57.78       4063+                 53.58   26  30  12
# 15                211  56.94       5363+                 46.22   15  28   4
# 53               254*  49.15       15924                 55.56   29  30  14
#
#      4s  6s
# 11  593  32
# 15  276   8
# 53  991  26

# %%
df[df["Player"].isin(["GS Sobers (WI)","JB Hobbs (ENG)","V Kohli (IND)"])]
# Out:
#             Player       Span  Matches  Inns  Not_Outs  Runs  \
# 10  GS Sobers (WI)  1954-1974       93   160        21  8032
# 11  GS Sobers (WI)  1954-1974       93   160        21  8032
# 14  JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 15  JB Hobbs (ENG)  1908-1930       61   102         7  5410
# 52   V Kohli (IND)  2011-2024      113   191        11  8848
# 53   V Kohli (IND)  2011-2024      113   191        11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50   0  \
# 10               365*  57.78       4063+                 53.58   26  30  12
# 11               365*  57.78       4063+                 53.58   26  30  12
# 14                211  56.94       5363+                 46.22   15  28   4
# 15                211  56.94       5363+                 46.22   15  28   4
# 52               254*  49.15       15924                 55.56   29  30  14
# 53               254*  49.15       15924                 55.56   29  30  14
#
# ...

# %%
# dropping duplicates
df = df.drop_duplicates()
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    HC Brook (ENG)  2022-2023       12    20         1  1181
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2               269*  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4               270*  60.83        416+                 56.00   10   5  2
#
#     4s  6s
# 0  626   6
# 1  141  23
# 2  186   5
# 3  246  11
# 4  104   1

# %%
# Split up Span into Start and End Date + career Length
df["Span"].str.split(pat = "-",expand = True)
# Out:
#        0     1
# 0   1928  1948
# 1   2022  2023
# 2   2015  2016
# 3   1963  1970
# 4   1930  1954
# 5   1924  1935
# 6   1931  1939
# 7   1955  1968
# 8   1948  1958
# 9   1927  1947
# 10  1954  1974
# 11  1954  1974
# 12  2000  2015
# 13  2010  2024
# 14  1908  1930
# 15  1908  1930
# 16  1948  1960
# 17  1937  1955
# 18  1995  2013
# 19  1921  1929
# 20  2010  2024
# 21  1968  1973
# 22  1993  1995
# 23  1970  1984
# 24  1935  1951
# 25  1989  2013
# 26  1990  2006
# 27  1976  1993
# 28  1996  2012
# 29  1998  2010
# 30  2000  2017
# 31  1995  2012
# 32  1920  1929
# 33  1992  2002
# 34  2005  2013
# 35  1994  2015
# 36  1971  1987
# 37  1985  2004
# 38  1994  2009
# 39  2004  2018
# 40  1978  1994
# 41  2019  2024
# 42  1974  1991
# 43  1937  1957
# 44  1997  2014
# 45  2012  2024
# 46  1992  2007
# 47  2018  2024
# 48  1948  1963
# 49  1911  1928
# 50  2001  2013
# 51  2019  2021
# 52  2011  2024
# 53  2011  2024
# 54  2004  2015
# 55  1961  1966
# 56  1929  1949
# ...

# %%
df[["Rookie_Year","Final_Year"]] = df["Span"].str.split("-",expand=True)

# %%
df
# Out:
#                       Player       Span  Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52    80        10   6996
# 1             HC Brook (ENG)  2022-2023       12    20         1   1181
# 2             AC Voges (AUS)  2015-2016       20    31         7   1485
# 3            RG Pollock (SA)  1963-1970       23    41         4   2256
# 4            GA Headley (WI)  1930-1954       22    40         4   2190
# 5          H Sutcliffe (ENG)  1924-1935       54    84         9   4555
# 6            E Paynter (ENG)  1931-1939       20    31         5   1540
# 7        KF Barrington (ENG)  1955-1968       82   131        15   6806
# 8             ED Weekes (WI)  1948-1958       48    81         5   4455
# 9           WR Hammond (ENG)  1927-1947       85   140        16   7249
# 10            GS Sobers (WI)  1954-1974       93   160        21   8032
# 12        KC Sangakkara (SL)  2000-2015      134   233        17  12400
# ...

# %%
# Dropping unusable columns
df = df.drop(["Span"],axis =1)

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 10            GS Sobers (WI)       93   160        21   8032
# 11            GS Sobers (WI)       93   160        21   8032
# 12        KC Sangakkara (SL)      134   233        17  12400
# 13           SPD Smith (AUS)      109   195        25   9685
# ...

# %%
# Question -> Split up the Country from the player

df["Player"].str.split(pat ="(" ,expand = True)
# Out:
#                     0         1
# 0         DG Bradman       AUS)
# 1           HC Brook       ENG)
# 2           AC Voges       AUS)
# 3         RG Pollock        SA)
# 4         GA Headley        WI)
# 5        H Sutcliffe       ENG)
# 6          E Paynter       ENG)
# 7      KF Barrington       ENG)
# 8          ED Weekes        WI)
# 9         WR Hammond       ENG)
# 10         GS Sobers        WI)
# 12     KC Sangakkara        SL)
# 13         SPD Smith       AUS)
# 14          JB Hobbs       ENG)
# 16        CL Walcott        WI)
# 17          L Hutton       ENG)
# 18         JH Kallis    ICC/SA)
# 19      GE Tyldesley       ENG)
# 20     KS Williamson        NZ)
# 21          CA Davis        WI)
# 22         VG Kambli       IND)
# 23       GS Chappell       AUS)
# 24         AD Nourse        SA)
# 25      SR Tendulkar       IND)
# 26           BC Lara    ICC/WI)
# 27     Javed Miandad       PAK)
# 28          R Dravid   ICC/IND)
# 29   Mohammad Yousuf       PAK)
# ...

# %%
df["Player"].str.split(pat = "(")
# Out:
# 0             [DG Bradman , AUS)]
# 1               [HC Brook , ENG)]
# 2               [AC Voges , AUS)]
# 3              [RG Pollock , SA)]
# 4              [GA Headley , WI)]
# 5            [H Sutcliffe , ENG)]
# 6              [E Paynter , ENG)]
# 7          [KF Barrington , ENG)]
# 8               [ED Weekes , WI)]
# 9             [WR Hammond , ENG)]
# 10              [GS Sobers , WI)]
# 11              [GS Sobers , WI)]
# 12          [KC Sangakkara , SL)]
# 13             [SPD Smith , AUS)]
# 14              [JB Hobbs , ENG)]
# 15              [JB Hobbs , ENG)]
# 16             [CL Walcott , WI)]
# 17              [L Hutton , ENG)]
# 18          [JH Kallis , ICC/SA)]
# 19          [GE Tyldesley , ENG)]
# 20          [KS Williamson , NZ)]
# 21               [CA Davis , WI)]
# 22             [VG Kambli , IND)]
# 23           [GS Chappell , AUS)]
# 24              [AD Nourse , SA)]
# 25          [SR Tendulkar , IND)]
# 26            [BC Lara , ICC/WI)]
# ...

# %%
df["Player_Name"] = df["Player"].str.split(pat = "(").str[0]

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 10            GS Sobers (WI)       93   160        21   8032
# 11            GS Sobers (WI)       93   160        21   8032
# 12        KC Sangakkara (SL)      134   233        17  12400
# 13           SPD Smith (AUS)      109   195        25   9685
# ...

# %%
df["Country"] = df["Player"].str.split(pat = "(").str[1]

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 10            GS Sobers (WI)       93   160        21   8032
# 12        KC Sangakkara (SL)      134   233        17  12400
# 13           SPD Smith (AUS)      109   195        25   9685
# 14            JB Hobbs (ENG)       61   102         7   5410
# ...

# %%
df["Country"].str.split(pat = ")")
# Out:
# 0         [AUS, ]
# 1         [ENG, ]
# 2         [AUS, ]
# 3          [SA, ]
# 4          [WI, ]
# 5         [ENG, ]
# 6         [ENG, ]
# 7         [ENG, ]
# 8          [WI, ]
# 9         [ENG, ]
# 10         [WI, ]
# 12         [SL, ]
# 13        [AUS, ]
# 14        [ENG, ]
# 16         [WI, ]
# 17        [ENG, ]
# 18     [ICC/SA, ]
# 19        [ENG, ]
# 20         [NZ, ]
# 21         [WI, ]
# 22        [IND, ]
# 23        [AUS, ]
# 24         [SA, ]
# 25        [IND, ]
# 26     [ICC/WI, ]
# 27        [PAK, ]
# 28    [ICC/IND, ]
# 29        [PAK, ]
# 30        [PAK, ]
# 31        [AUS, ]
# 32        [AUS, ]
# 33        [ZIM, ]
# 34        [AUS, ]
# 35         [WI, ]
# 36        [IND, ]
# 37        [AUS, ]
# 38        [AUS, ]
# 39         [SA, ]
# 40        [AUS, ]
# 41         [NZ, ]
# 42         [WI, ]
# 43        [ENG, ]
# 44         [SL, ]
# 45        [ENG, ]
# 46    [ICC/PAK, ]
# 47        [AUS, ]
# 48         [WI, ]
# 49        [ENG, ]
# 50    [ICC/IND, ]
# 51        [PAK, ]
# ...

# %%
df["Country"] = df["Country"].str.split(pat = ")").str[0]

# %%
df
# Out:
#                       Player  Matches  Inns  Not_Outs   Runs  \
# 0           DG Bradman (AUS)       52    80        10   6996
# 1             HC Brook (ENG)       12    20         1   1181
# 2             AC Voges (AUS)       20    31         7   1485
# 3            RG Pollock (SA)       23    41         4   2256
# 4            GA Headley (WI)       22    40         4   2190
# 5          H Sutcliffe (ENG)       54    84         9   4555
# 6            E Paynter (ENG)       20    31         5   1540
# 7        KF Barrington (ENG)       82   131        15   6806
# 8             ED Weekes (WI)       48    81         5   4455
# 9           WR Hammond (ENG)       85   140        16   7249
# 10            GS Sobers (WI)       93   160        21   8032
# 12        KC Sangakkara (SL)      134   233        17  12400
# 13           SPD Smith (AUS)      109   195        25   9685
# 14            JB Hobbs (ENG)       61   102         7   5410
# ...

# %%
df = df.drop(["Player"],axis =1)

# %%
df
# Out:
#     Matches  Inns  Not_Outs   Runs Highest_Inns_Score    Ave Balls_Faced  \
# 0        52    80        10   6996                334  99.94       9800+
# 1        12    20         1   1181                186  62.15        1287
# 2        20    31         7   1485               269*  61.87        2667
# 3        23    41         4   2256                274  60.97       1707+
# 4        22    40         4   2190               270*  60.83        416+
# 5        54    84         9   4555                194  60.73       6558+
# 6        20    31         5   1540                243  59.23       1288+
# 7        82   131        15   6806                256  58.67       4957+
# 8        48    81         5   4455                207  58.61           0
# 9        85   140        16   7249               336*  58.45       7491+
# 10       93   160        21   8032               365*  57.78       4063+
# 11       93   160        21   8032               365*  57.78       4063+
# ...

# %%
df.head()
# Out:
#    Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave Balls_Faced  \
# 0       52    80        10  6996                334  99.94       9800+
# 1       12    20         1  1181                186  62.15        1287
# 2       20    31         7  1485               269*  61.87        2667
# 3       23    41         4  2256                274  60.97       1707+
# 4       22    40         4  2190               270*  60.83        416+
#
#    Battling_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year  \
# 0                 58.60   29  13  7  626   6        1928       1948
# 1                 91.76    4   7  1  141  23        2022       2023
# 2                 55.68    5   4  2  186   5        2015       2016
# 3                 54.48    7  11  1  246  11        1963       1970
# 4                 56.00   10   5  2  104   1        1930       1954
#
#    Player_Name Country
# 0  DG Bradman      AUS
# 1    HC Brook      ENG
# 2    AC Voges      AUS
# 3  RG Pollock       SA
# ...

# %%
df = df[["Player_Name","Country","Rookie_Year","Final_Year","Matches","Inns","Not_Outs","Runs","Highest_Inns_Score","Ave","Balls_Faced","Battling_Strike_Rate","100","50","0","4s","6s"]]

# %%
df.head()
# Out:
#    Player_Name Country Rookie_Year Final_Year  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman      AUS        1928       1948       52    80        10  6996
# 1    HC Brook      ENG        2022       2023       12    20         1  1181
# 2    AC Voges      AUS        2015       2016       20    31         7  1485
# 3  RG Pollock       SA        1963       1970       23    41         4  2256
# 4  GA Headley       WI        1930       1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2               269*  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4               270*  60.83        416+                 56.00   10   5  2
#
#     4s  6s
# 0  626   6
# 1  141  23
# 2  186   5
# ...

# %%
# Change Data Types
df.dtypes
# Out:
# Player_Name              object
# Country                  object
# Rookie_Year              object
# Final_Year               object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Score       object
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int64
# 6s                        int64
# dtype: object

# %%
df["Highest_Inns_Score"].str.split(pat="*").str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
# 5     194
# 6     243
# 7     256
# 8     207
# 9     336
# 10    365
# 12    319
# 13    239
# 14    211
# 16    220
# 17    364
# 18    224
# 19    122
# 20    251
# 21    183
# 22    227
# 23    247
# 24    231
# 25    248
# 26    400
# 27    280
# 28    270
# 29    223
# 30    313
# 31    257
# 32    201
# 33    232
# 34    195
# 35    203
# 36    236
# 37    200
# 38    380
# 39    278
# 40    205
# 41    190
# 42    291
# 43    278
# 44    374
# 45    254
# 46    329
# 47    215
# 48    261
# 49    182
# 50    319
# 51    215
# 52    254
# 54    329
# 55    144
# 56    189
# 57    144
# 58    231
# 59    205
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_Score, dtype: object

# %%
df["Highest_Inns_Score"]=df["Highest_Inns_Score"].str.split(pat="*").str[0]

# %%
df.head()
# Out:
#    Player_Name Country Rookie_Year Final_Year  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman      AUS        1928       1948       52    80        10  6996
# 1    HC Brook      ENG        2022       2023       12    20         1  1181
# 2    AC Voges      AUS        2015       2016       20    31         7  1485
# 3  RG Pollock       SA        1963       1970       23    41         4  2256
# 4  GA Headley       WI        1930       1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                 58.60   29  13  7
# 1                186  62.15        1287                 91.76    4   7  1
# 2                269  61.87        2667                 55.68    5   4  2
# 3                274  60.97       1707+                 54.48    7  11  1
# 4                270  60.83        416+                 56.00   10   5  2
#
#     4s  6s
# 0  626   6
# 1  141  23
# 2  186   5
# ...

# %%
# set the appropriate data type
df["Highest_Inns_Score"] = df["Highest_Inns_Score"].astype("int")

# %%
df.dtypes
# Out:
# Player_Name              object
# Country                  object
# Rookie_Year              object
# Final_Year               object
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Score        int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int64
# 6s                        int64
# dtype: object

# %%
## QUESTION SEE IF YOU CAN FIX Rookie Year and Final Year
# Set multiple data type in one syntax

df = df.astype({"Rookie_Year":"int","Final_Year":"int"})

# %%
df["Balls_Faced"] = df["Balls_Faced"].str.split(pat = "+").str[0]

# %%
df.head()
# Out:
#    Player_Name Country  Rookie_Year  Final_Year  Matches  Inns  Not_Outs  \
# 0  DG Bradman      AUS         1928        1948       52    80        10
# 1    HC Brook      ENG         2022        2023       12    20         1
# 2    AC Voges      AUS         2015        2016       20    31         7
# 3  RG Pollock       SA         1963        1970       23    41         4
# 4  GA Headley       WI         1930        1954       22    40         4
#
#    Runs  Highest_Inns_Score    Ave Balls_Faced  Battling_Strike_Rate  100  50  \
# 0  6996                 334  99.94        9800                 58.60   29  13
# 1  1181                 186  62.15        1287                 91.76    4   7
# 2  1485                 269  61.87        2667                 55.68    5   4
# 3  2256                 274  60.97        1707                 54.48    7  11
# 4  2190                 270  60.83         416                 56.00   10   5
#
#    0   4s  6s
# 0  7  626   6
# 1  1  141  23
# ...

# %%
df.dtypes
# Out:
# Player_Name              object
# Country                  object
# Rookie_Year               int32
# Final_Year                int32
# Matches                   int64
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Score        int32
# Ave                     float64
# Balls_Faced              object
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int64
# 6s                        int64
# dtype: object

# %%
df["Balls_Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
# 5      6558
# 6      1288
# 7      4957
# 8       NaN
# 9      7491
# 10     4063
# 12    22882
# 13    18100
# 14     5363
# 16      NaN
# 17     2844
# 18    28903
# 19      178
# 20    17006
# 21      665
# 22     1823
# 23    13079
# 24      108
# 25    29437
# 26    19753
# 27    15164
# 28    31258
# 29    14372
# 30    19375
# 31    22782
# 32     2035
# 33    10636
# 34    12436
# 35    27395
# 36    14184
# 37    22461
# 38    14349
# 39    16077
# 40    27002
# 41     3014
# 42     9613
# 43     2731
# 44    22959
# 45    20762
# 46    16345
# 47     7809
# 48      488
# 49      619
# 50    10441
# 51     2445
# 52    15924
# 54    15456
# 55      885
# 56      158
# 57      NaN
# 58    11641
# 59     1799
# 60     8662
# 61    15525
# 62     3118
# 63     3217
# 64     2110
# Name: Balls_Faced, dtype: object

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df["Balls_Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
# 5      6558
# 6      1288
# 7      4957
# 8         0
# 9      7491
# 10     4063
# 12    22882
# 13    18100
# 14     5363
# 16        0
# 17     2844
# 18    28903
# 19      178
# 20    17006
# 21      665
# 22     1823
# 23    13079
# 24      108
# 25    29437
# 26    19753
# 27    15164
# 28    31258
# 29    14372
# 30    19375
# 31    22782
# 32     2035
# 33    10636
# 34    12436
# 35    27395
# 36    14184
# 37    22461
# 38    14349
# 39    16077
# 40    27002
# 41     3014
# 42     9613
# 43     2731
# 44    22959
# 45    20762
# 46    16345
# 47     7809
# 48      488
# 49      619
# 50    10441
# 51     2445
# 52    15924
# 54    15456
# 55      885
# 56      158
# 57        0
# 58    11641
# 59     1799
# 60     8662
# 61    15525
# 62     3118
# 63     3217
# 64     2110
# Name: Balls_Faced, dtype: object

# %%
df["Balls_Faced"] = df["Balls_Faced"].astype("int")

# %%
df["Matches"]= df["Matches"].astype("int")

# %%
df.dtypes
# Out:
# Player_Name              object
# Country                  object
# Rookie_Year               int32
# Final_Year                int32
# Matches                   int32
# Inns                      int64
# Not_Outs                  int64
# Runs                      int64
# Highest_Inns_Score        int32
# Ave                     float64
# Balls_Faced               int32
# Battling_Strike_Rate    float64
# 100                       int64
# 50                        int64
# 0                         int64
# 4s                        int64
# 6s                        int64
# dtype: object

# %%
df.head(5)     # - semua data types dah ubah
# Out:
#    Player_Name Country  Rookie_Year  Final_Year  Matches  Inns  Not_Outs  \
# 0  DG Bradman      AUS         1928        1948       52    80        10
# 1    HC Brook      ENG         2022        2023       12    20         1
# 2    AC Voges      AUS         2015        2016       20    31         7
# 3  RG Pollock       SA         1963        1970       23    41         4
# 4  GA Headley       WI         1930        1954       22    40         4
#
#    Runs  Highest_Inns_Score    Ave  Balls_Faced  Battling_Strike_Rate  100  \
# 0  6996                 334  99.94         9800                 58.60   29
# 1  1181                 186  62.15         1287                 91.76    4
# 2  1485                 269  61.87         2667                 55.68    5
# 3  2256                 274  60.97         1707                 54.48    7
# 4  2190                 270  60.83          416                 56.00   10
#
#    50  0   4s  6s
# 0  13  7  626   6
# 1   7  1  141  23
# ...

# %%
# Build Out Career_Length
df["Career_Length"] = df["Final_Year"] - df["Rookie_Year"]
df["Career_Length"]
# Out:
# 0     20
# 1      1
# 2      1
# 3      7
# 4     24
# 5     11
# 6      8
# 7     13
# 8     10
# 9     20
# 10    20
# 12    15
# 13    14
# 14    22
# 16    12
# 17    18
# 18    18
# 19     8
# 20    14
# 21     5
# 22     2
# 23    14
# 24    16
# 25    24
# 26    16
# 27    17
# 28    16
# 29    12
# 30    17
# 31    17
# 32     9
# 33    10
# 34     8
# 35    21
# 36    16
# 37    19
# 38    15
# 39    14
# 40    16
# 41     5
# 42    17
# 43    20
# 44    17
# 45    12
# 46    15
# 47     6
# 48    15
# 49    17
# 50    12
# 51     2
# 52    13
# 54    11
# 55     5
# 56    20
# 57    12
# 58    12
# 59    15
# 60    16
# 61    12
# 62    10
# 63     8
# 64     6
# Name: Career_Length, dtype: int32

# %% [markdown]
# # Calculations

# %%
#1. What is the Average Career Lenghth

df["Career_Length"].mean()
# Out:
# 13.193548387096774

# %%
#2. AVG Batting Strike Rate for Cricketers Who played over 10 years
df[df["Career_Length"] >10]["Battling_Strike_Rate"].mean()
# Out:
# 47.94681818181819

# %%
#3. Find cricketers who played before 1960

# %%
df[df["Rookie_Year"] < 1960]["Player_Name"].count()
# Out:
# 23

# %%
#4. Max Highest Inns Score by Country

df.groupby("Country")["Highest_Inns_Score"].max().to_frame("HihghInnCountry").reset_index().sort_values("HihghInnCountry",ascending = False)
# Out:
#     Country  HihghInnCountry
# 5    ICC/WI              400
# 0       AUS              380
# 10       SL              374
# 11       WI              365
# 1       ENG              364
# 3   ICC/PAK              329
# 2   ICC/IND              319
# 8       PAK              313
# 9        SA              278
# 4    ICC/SA              277
# 6       IND              254
# 7        NZ              251
# 12      ZIM              232

# %%
#5. Hundreds, Fifties, ducks (0) AVG by Country
df.groupby("Country")[["100","50","0"]].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.384615  20.846154   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000

# %%
df.head(5)
# Out:
#    Player_Name Country  Rookie_Year  Final_Year  Matches  Inns  Not_Outs  \
# 0  DG Bradman      AUS         1928        1948       52    80        10
# 1    HC Brook      ENG         2022        2023       12    20         1
# 2    AC Voges      AUS         2015        2016       20    31         7
# 3  RG Pollock       SA         1963        1970       23    41         4
# 4  GA Headley       WI         1930        1954       22    40         4
#
#    Runs  Highest_Inns_Score    Ave  Balls_Faced  Battling_Strike_Rate  100  \
# 0  6996                 334  99.94         9800                 58.60   29
# 1  1181                 186  62.15         1287                 91.76    4
# 2  1485                 269  61.87         2667                 55.68    5
# 3  2256                 274  60.97         1707                 54.48    7
# 4  2190                 270  60.83          416                 56.00   10
#
#    50  0   4s  6s  Career_Length
# 0  13  7  626   6             20
# ...

# %%
df
# Out:
#           Player_Name  Country  Rookie_Year  Final_Year  Matches  Inns  \
# 0         DG Bradman       AUS         1928        1948       52    80
# 1           HC Brook       ENG         2022        2023       12    20
# 2           AC Voges       AUS         2015        2016       20    31
# 3         RG Pollock        SA         1963        1970       23    41
# 4         GA Headley        WI         1930        1954       22    40
# 5        H Sutcliffe       ENG         1924        1935       54    84
# 6          E Paynter       ENG         1931        1939       20    31
# 7      KF Barrington       ENG         1955        1968       82   131
# 8          ED Weekes        WI         1948        1958       48    81
# 9         WR Hammond       ENG         1927        1947       85   140
# 10         GS Sobers        WI         1954        1974       93   160
# 12     KC Sangakkara        SL         2000        2015      134   233
# ...

# %%
# saving file to excel

df.to_excel('Cleaned_Cricket_Test_match_data.xlsx', index = False)

# %%
# saving file to csv

df.to_csv('Cleaned_Cricket_Test_Match_Data.csv', index = False)
