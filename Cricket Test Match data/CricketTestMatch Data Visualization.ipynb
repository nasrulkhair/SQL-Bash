# %% [markdown]
# # Visualization Using Phyton

# %%
import pandas as pd
import numpy as nmp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\User\OneDrive\Desktop\Data Analyst\PHYTON\Datasets\Cricket Test Match data\CricketTestMatchData_Cleaned.csv")

# %%
df
# Out:
#      Player_Name Country  Rookie_Year  Final_Year  Matches  Inns  Not_Outs  \
# 0    DG Bradman      AUS         1928        1948       52    80        10
# 1      HC Brook      ENG         2022        2023       12    20         1
# 2      AC Voges      AUS         2015        2016       20    31         7
# 3    RG Pollock       SA         1963        1970       23    41         4
# 4    GA Headley       WI         1930        1954       22    40         4
# ..           ...     ...          ...         ...      ...   ...       ...
# 57   KD Walters      AUS         1965        1981       74   125        14
# 58     GC Smith   ICC/SA         2002        2014      117   205        13
# 59  WH Ponsford      AUS         1924        1934       29    48         4
# 60    SJ McCabe      AUS         1930        1938       39    62         5
# 61   DR Jardine      ENG         1928        1934       22    33         6
#
# ...

# %%
df = df.set_index("Country")

# %%
df
# Out:
#          Rookie_Year  Final_Year  Matches  Inns  Not_Outs  Runs  \
# Country
# AUS             1928        1948       52    80        10  6996
# ENG             2022        2023       12    20         1  1181
# AUS             2015        2016       20    31         7  1485
# SA              1963        1970       23    41         4  2256
# WI              1930        1954       22    40         4  2190
# ...              ...         ...      ...   ...       ...   ...
# AUS             1965        1981       74   125        14  5357
# ICC/SA          2002        2014      117   205        13  9265
# AUS             1924        1934       29    48         4  2122
# AUS             1930        1938       39    62         5  2748
# ENG             1928        1934       22    33         6  1296
#
#          Highest_Inns_Score    Ave  Balls_Faced  Battling_Strike_Rate  100  \
# Country
# AUS                     334  99.94         9800                 58.60   29
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
df.plot(kind = 'line', title = 'Country Matches', xlabel = 'Country', ylabel = 'Matches')
# Out:
# <Axes: title={'center': 'Country Matches'}, xlabel='Country', ylabel='Matches'>
